# %%
import seaborn as sns
import pandas as pd
import numpy as np
df =pd.read_csv("diamonds.csv")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df=df.drop_duplicates()

# %%
df=df.drop(columns=["x","y","z"],axis=1,errors="ignore")

# %%
df.shape
# Out:
# (53794, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  object
#  2   color    53794 non-null  object
#  3   clarity  53794 non-null  object
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 3.3+ MB

# %%
# target variable

y=df["price"]
df.shape
# Out:
# (53794, 7)

# %%
#input variable
X=df.drop(columns="price")
X.shape
# Out:
# (53794, 6)

# %%
# splitting data into test and train

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (40345, 6)
# (13449, 6)
# (40345,)
# (13449,)

# %%
#feature scaling

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder,StandardScaler
transformer=ColumnTransformer(transformers=[("t1",OrdinalEncoder(),[1,2,3]),
                                          ("t2",StandardScaler(),[0,4,5])])

# %%
transformer
# Out:
# ColumnTransformer(transformers=[('t1', OrdinalEncoder(), [1, 2, 3]),
#                                 ('t2', StandardScaler(), [0, 4, 5])])

# %%
X_train_trans=transformer.fit_transform(X_train)
X_test_trans=transformer.transform(X_test)

# %%
import pandas as pd
X_train_trans=pd.DataFrame(X_train_trans)

# %%
X_train_trans.head()
# Out:
#      0    1    2         3         4         5
# 0  2.0  2.0  6.0 -1.069888 -0.593163 -0.202692
# 1  2.0  0.0  4.0 -0.331506 -0.173317 -0.650277
# 2  4.0  0.0  5.0  0.449069  0.106581  0.692478
# 3  1.0  1.0  7.0  0.449069  1.715990 -0.202692
# 4  2.0  5.0  7.0 -1.006598  0.316504 -1.321655

# %% [markdown]
# # KNN Model Buliding

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train_trans,y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# # Prediction

# %%
y_pred=knn.predict(X_test_trans)
print(y_pred.shape)
print(y_test.shape)
# Out:
# (13449,)
# (13449,)

# %% [markdown]
# # R2_Score

# %%
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)
score
# Out:
# 0.9450752140259143

# %% [markdown]
# # mean_absolute_error

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
score=mean_absolute_error(y_pred,y_test)
score
# Out:
# 503.8838277938881

# %% [markdown]
# # mean_squared_error

# %%
score=mean_squared_error(y_pred,y_test)
score
# Out:
# 766480.169767269

# %%
import pickle

# %%
import pickle

with open(r"C:\Users\Sai teja\OneDrive\Desktop\Diamond\diamond_prediction_model.pkl", "wb") as file:
    pickle.dump(knn, file)

# %%
import os
os.path.exists(r"C:\Users\Sai teja\OneDrive\Desktop\Diamond\diamond_prediction_model.pkl")
# Out:
# True

# %%
with open("diamond_prediction_model.pkl", "rb") as file:
    model = pickle.load(file)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Sai teja
